# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

data1 = h5py.File('../data/MNIST_BE_20220208_1.mat','r')

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

data1 = h5py.File('../data/MNIST_BE_20220208_1.mat','r')
data2 = h5py.File('../data/MNIST_BE_20220208_2.mat','r')
data3 = h5py.File('../data/MNIST_BE_20220208_3.mat','r')
data4 = h5py.File('../data/MNIST_BE_20220208_4.mat','r')
data5 = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_1.mat','r')
data6 = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_2.mat','r')
data7 = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_3.mat','r')
data8 = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_4.mat','r')

n = 200
data1["acc_train_history"][:n];
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = 24, 9
plt.rcParams.update({'font.size': 18})

epochs = np.arange(1, 201)

fig, ((ax11, ax12, ax13, ax14),(ax21, ax22, ax23, ax24)) = plt.subplots(2, 4)

ax11.text(-60, 1.01, 'a', fontsize='large', fontweight='bold')
ax11.set_ylim([0.5,1])
ax11.set_ylabel('Accuracy')
ax11.set_xlabel('Epochs')
ax11.plot(epochs, data1["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax11.plot(epochs, data1["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax11.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax11copy = ax11.twinx()  # instantiate a second axes that shares the same x-axis
ax11copy.set_ylim(0.3, 0.75)
# ax11copy.set_ylabel('Loss')
ax11copy.plot(epochs, data1["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax11copy.plot(epochs, data1["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax11copy.legend(frameon=False, loc=(0.12,0.1), labelspacing=0)

ax12.text(-60, 1.01, 'b', fontsize='large', fontweight='bold')
ax12.set_ylim([0.5,1])
ax12.set_xlabel('Epochs')
# ax12.set_ylabel('Accuracy')
ax12.plot(epochs, data2["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax12.plot(epochs, data2["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax12.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax12copy = ax12.twinx()  # instantiate a second axes that shares the same x-axis
ax12copy.set_ylim(0.3, 0.75)
# ax12copy.set_ylabel('Loss')
ax12copy.plot(epochs, data2["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax12copy.plot(epochs, data2["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax12copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax13.text(-60, 1.01, 'c', fontsize='large', fontweight='bold')
ax13.set_ylim([0.5,1])
ax13.set_xlabel('Epochs')
# ax21.set_ylabel('Accuracy')
ax13.plot(epochs, data3["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax13.plot(epochs, data3["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax13.legend(frameon=False, loc=(0.22,0.63), labelspacing=0)
ax13copy = ax13.twinx()  # instantiate a second axes that shares the same x-axis
ax13copy.set_ylim(0.3, 0.75)
# ax21copy.set_ylabel('Loss')
ax13copy.plot(epochs, data3["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax13copy.plot(epochs, data3["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax13copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax14.text(-60, 1.01, 'd', fontsize='large', fontweight='bold')
ax14.set_ylim([0.5,1])
ax14.set_xlabel('Epochs')
# ax22.set_ylabel('Accuracy')
ax14.plot(epochs, data4["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax14.plot(epochs, data4["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax14.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax14copy = ax14.twinx()  # instantiate a second axes that shares the same x-axis
ax14copy.set_ylim(0.3, 0.75)
ax14copy.set_ylabel('Loss')
ax14copy.plot(epochs, data4["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax14copy.plot(epochs, data4["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax14copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax21.text(-60, 1.01, 'e', fontsize='large', fontweight='bold')
ax21.set_ylim([0.5,1])
ax21.set_ylabel('Accuracy')
ax21.set_xlabel('Epochs')
ax21.plot(epochs, data5["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax21.plot(epochs, data5["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax21.legend(frameon=False, loc=(0.23,0.17), labelspacing=0)
ax21copy = ax21.twinx()  # instantiate a second axes that shares the same x-axis
ax21copy.set_ylim(0.3, 0.75)
# ax11copy.set_ylabel('Loss')
ax21copy.plot(epochs, data5["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax21copy.plot(epochs, data5["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax21copy.legend(frameon=False, loc=(0.23,-0.03), labelspacing=0)

ax22.text(-60, 1.01, 'f', fontsize='large', fontweight='bold')
ax22.set_ylim([0.5,1])
ax22.set_xlabel('Epochs')
# ax12.set_ylabel('Accuracy')
ax22.plot(epochs, data6["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax22.plot(epochs, data6["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax22.legend(frameon=False, loc=(0.23,0.2), labelspacing=0)
ax22copy = ax22.twinx()  # instantiate a second axes that shares the same x-axis
ax22copy.set_ylim(0.3, 0.75)
# ax12copy.set_ylabel('Loss')
ax22copy.plot(epochs, data6["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax22copy.plot(epochs, data6["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax22copy.legend(frameon=False, loc=(0.23,0.00), labelspacing=0)

ax23.text(-60, 1.01, 'g', fontsize='large', fontweight='bold')
ax23.set_ylim([0.5,1])
ax23.set_xlabel('Epochs')
# ax21.set_ylabel('Accuracy')
ax23.plot(epochs, data7["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax23.plot(epochs, data7["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax23.legend(frameon=False, loc=(0.23,0.2), labelspacing=0)
ax23copy = ax23.twinx()  # instantiate a second axes that shares the same x-axis
ax23copy.set_ylim(0.3, 0.75)
# ax21copy.set_ylabel('Loss')
ax23copy.plot(epochs, data7["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax23copy.plot(epochs, data7["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax23copy.legend(frameon=False, loc=(0.23,0.00), labelspacing=0)

ax24.text(-60, 1.01, 'h', fontsize='large', fontweight='bold')
ax24.set_ylim([0.5,1])
ax24.set_xlabel('Epochs')
# ax22.set_ylabel('Accuracy')
ax24.plot(epochs, data8["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax24.plot(epochs, data8["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax24.legend(frameon=False, loc=(0.23,0.23), labelspacing=0)
ax24copy = ax24.twinx()  # instantiate a second axes that shares the same x-axis
ax24copy.set_ylim(0.3, 0.75)
ax24copy.set_ylabel('Loss')
ax24copy.plot(epochs, data8["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax24copy.plot(epochs, data8["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax24copy.legend(frameon=False, loc=(0.23,0.03), labelspacing=0)

plt.tight_layout()

# plt.savefig('benchmark_mnist.pdf', bbox_inches='tight', pad_inches=0) 
plt.show()

# %%
data1 = h5py.File('../data/FashionMNIST_BE_20220208_1.mat','r')
data2 = h5py.File('../data/FashionMNIST_BE_20220208_2.mat','r')
data3 = h5py.File('../data/FashionMNIST_BE_20220208_3.mat','r')
data4 = h5py.File('../data/FashionMNIST_BE_20220208_4.mat','r')
data5 = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_1.mat','r')
data6 = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_2.mat','r')
data7 = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_3.mat','r')
data8 = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_4.mat','r')

n = 200
data1["acc_train_history"][:n];
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['figure.figsize'] = 24, 9
plt.rcParams.update({'font.size': 18})

epochs = np.arange(1, 201)

fig, ((ax11, ax12, ax13, ax14),(ax21, ax22, ax23, ax24)) = plt.subplots(2, 4)

ax11.text(-60, 1.01, 'a', fontsize='large', fontweight='bold')
ax11.set_ylim([0.5,1])
ax11.set_ylabel('Accuracy')
ax11.set_xlabel('Epochs')
ax11.plot(epochs, data1["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax11.plot(epochs, data1["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax11.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax11copy = ax11.twinx()  # instantiate a second axes that shares the same x-axis
ax11copy.set_ylim(0.3, 0.75)
# ax11copy.set_ylabel('Loss')
ax11copy.plot(epochs, data1["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax11copy.plot(epochs, data1["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax11copy.legend(frameon=False, loc=(0.12,0.1), labelspacing=0)

ax12.text(-60, 1.01, 'b', fontsize='large', fontweight='bold')
ax12.set_ylim([0.5,1])
ax12.set_xlabel('Epochs')
# ax12.set_ylabel('Accuracy')
ax12.plot(epochs, data2["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax12.plot(epochs, data2["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax12.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax12copy = ax12.twinx()  # instantiate a second axes that shares the same x-axis
ax12copy.set_ylim(0.3, 0.75)
# ax12copy.set_ylabel('Loss')
ax12copy.plot(epochs, data2["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax12copy.plot(epochs, data2["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax12copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax13.text(-60, 1.01, 'c', fontsize='large', fontweight='bold')
ax13.set_ylim([0.5,1])
ax13.set_xlabel('Epochs')
# ax21.set_ylabel('Accuracy')
ax13.plot(epochs, data3["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax13.plot(epochs, data3["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax13.legend(frameon=False, loc=(0.22,0.63), labelspacing=0)
ax13copy = ax13.twinx()  # instantiate a second axes that shares the same x-axis
ax13copy.set_ylim(0.3, 0.75)
# ax21copy.set_ylabel('Loss')
ax13copy.plot(epochs, data3["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax13copy.plot(epochs, data3["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax13copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax14.text(-60, 1.01, 'd', fontsize='large', fontweight='bold')
ax14.set_ylim([0.5,1])
ax14.set_xlabel('Epochs')
# ax22.set_ylabel('Accuracy')
ax14.plot(epochs, data4["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax14.plot(epochs, data4["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax14.legend(frameon=False, loc=(0.22,0.6), labelspacing=0)
ax14copy = ax14.twinx()  # instantiate a second axes that shares the same x-axis
ax14copy.set_ylim(0.3, 0.75)
ax14copy.set_ylabel('Loss')
ax14copy.plot(epochs, data4["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax14copy.plot(epochs, data4["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax14copy.legend(frameon=False, loc=(0.2,0.1), labelspacing=0)

ax21.text(-60, 1.01, 'e', fontsize='large', fontweight='bold')
ax21.set_ylim([0.5,1])
ax21.set_ylabel('Accuracy')
ax21.set_xlabel('Epochs')
ax21.plot(epochs, data5["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax21.plot(epochs, data5["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax21.legend(frameon=False, loc=(0.23,0.17), labelspacing=0)
ax21copy = ax21.twinx()  # instantiate a second axes that shares the same x-axis
ax21copy.set_ylim(0.3, 0.75)
# ax11copy.set_ylabel('Loss')
ax21copy.plot(epochs, data5["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax21copy.plot(epochs, data5["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax21copy.legend(frameon=False, loc=(0.23,-0.03), labelspacing=0)

ax22.text(-60, 1.01, 'f', fontsize='large', fontweight='bold')
ax22.set_ylim([0.5,1])
ax22.set_xlabel('Epochs')
# ax12.set_ylabel('Accuracy')
ax22.plot(epochs, data6["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax22.plot(epochs, data6["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax22.legend(frameon=False, loc=(0.23,0.2), labelspacing=0)
ax22copy = ax22.twinx()  # instantiate a second axes that shares the same x-axis
ax22copy.set_ylim(0.3, 0.75)
# ax12copy.set_ylabel('Loss')
ax22copy.plot(epochs, data6["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax22copy.plot(epochs, data6["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax22copy.legend(frameon=False, loc=(0.23,0.00), labelspacing=0)

ax23.text(-60, 1.01, 'g', fontsize='large', fontweight='bold')
ax23.set_ylim([0.5,1])
ax23.set_xlabel('Epochs')
# ax21.set_ylabel('Accuracy')
ax23.plot(epochs, data7["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax23.plot(epochs, data7["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax23.legend(frameon=False, loc=(0.23,0.2), labelspacing=0)
ax23copy = ax23.twinx()  # instantiate a second axes that shares the same x-axis
ax23copy.set_ylim(0.3, 0.75)
# ax21copy.set_ylabel('Loss')
ax23copy.plot(epochs, data7["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax23copy.plot(epochs, data7["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax23copy.legend(frameon=False, loc=(0.23,0.00), labelspacing=0)

ax24.text(-60, 1.01, 'h', fontsize='large', fontweight='bold')
ax24.set_ylim([0.5,1])
ax24.set_xlabel('Epochs')
# ax22.set_ylabel('Accuracy')
ax24.plot(epochs, data8["acc_train_history"][:n], color='tab:blue', marker='o', fillstyle='none', markevery=10, alpha=0.8, label='training accuracy')
ax24.plot(epochs, data8["acc_test_history"][:n], color='tab:orange', marker='^', fillstyle='none', markevery=10, alpha=0.8, label='test accuracy')
ax24.legend(frameon=False, loc=(0.23,0.23), labelspacing=0)
ax24copy = ax24.twinx()  # instantiate a second axes that shares the same x-axis
ax24copy.set_ylim(0.3, 0.75)
ax24copy.set_ylabel('Loss')
ax24copy.plot(epochs, data8["loss_train_history"][:n], color='tab:green', marker='D', fillstyle='none', markevery=10, alpha=0.8, label='training loss')
ax24copy.plot(epochs, data8["loss_test_history"][:n], color='tab:red', marker='s', fillstyle='none', markevery=10, alpha=0.8, label='test loss')
ax24copy.legend(frameon=False, loc=(0.23,0.03), labelspacing=0)

plt.tight_layout()

# plt.savefig('benchmark_fashionmnist.pdf', bbox_inches='tight', pad_inches=0) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

n = 200
epochs = np.arange(1, n+1)
m = 10

err_BE_acc_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_train_history"][ind])
    err_BE_acc_train_history.append(np.std(E))

err_BE_acc_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_test_history"][ind])
    err_BE_acc_test_history.append(np.std(E))
    
err_BE_loss_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_train_history"][ind])
    err_BE_loss_train_history.append(np.std(E))

err_BE_loss_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_test_history"][ind])
    err_BE_loss_test_history.append(np.std(E))

#####################################################################################
    
err_BE_EncodingFirst_acc_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_train_history"][ind])
    err_BE_EncodingFirst_acc_train_history.append(np.std(E))

err_BE_EncodingFirst_acc_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_test_history"][ind])
    err_BE_EncodingFirst_acc_test_history.append(np.std(E))
    
err_BE_EncodingFirst_loss_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_train_history"][ind])
    err_BE_EncodingFirst_loss_train_history.append(np.std(E))

err_BE_EncodingFirst_loss_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_test_history"][ind])
    err_BE_EncodingFirst_loss_test_history.append(np.std(E))

# %%
mean_BE_acc_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_acc_train_history = mean_BE_acc_train_history + data["acc_train_history"][:]
mean_BE_acc_train_history = mean_BE_acc_train_history/m
mean_BE_acc_train_history

mean_BE_acc_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_acc_test_history = mean_BE_acc_test_history + data["acc_test_history"][:]
mean_BE_acc_test_history = mean_BE_acc_test_history/m
mean_BE_acc_test_history

mean_BE_EncodingFirst_acc_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_acc_train_history = mean_BE_EncodingFirst_acc_train_history + data["acc_train_history"][:]
mean_BE_EncodingFirst_acc_train_history = mean_BE_EncodingFirst_acc_train_history/m
mean_BE_EncodingFirst_acc_train_history

mean_BE_EncodingFirst_acc_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_acc_test_history = mean_BE_EncodingFirst_acc_test_history + data["acc_test_history"][:]
mean_BE_EncodingFirst_acc_test_history = mean_BE_EncodingFirst_acc_test_history/m

# %%
mean_BE_loss_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_loss_train_history = mean_BE_loss_train_history + data["loss_train_history"][:]
mean_BE_loss_train_history = mean_BE_loss_train_history/m
mean_BE_loss_train_history

mean_BE_loss_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_loss_test_history = mean_BE_loss_test_history + data["loss_test_history"][:]
mean_BE_loss_test_history = mean_BE_loss_test_history/m
mean_BE_loss_test_history

mean_BE_EncodingFirst_loss_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_loss_train_history = mean_BE_EncodingFirst_loss_train_history + data["loss_train_history"][:]
mean_BE_EncodingFirst_loss_train_history = mean_BE_EncodingFirst_loss_train_history/m
mean_BE_EncodingFirst_loss_train_history

mean_BE_EncodingFirst_loss_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/MNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_loss_test_history = mean_BE_EncodingFirst_loss_test_history + data["loss_test_history"][:]
mean_BE_EncodingFirst_loss_test_history = mean_BE_EncodingFirst_loss_test_history/m

# %%
# data1["acc_train_history"][:n];
# plt.rcParams["font.family"] = "Times New Roman"
# plt.rcParams['figure.figsize'] = 24, 9
plt.rcParams.update({'font.size': 24})

cmap = plt.cm.get_cmap('coolwarm')
rgba = cmap(np.linspace(0., 1.0, 2))

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True,
                                    figsize=(24, 8))
e = 3
mark_s = 7
mark_e = 6

#ax0.set_title('')
ax0.text(-25, 1.03, 'a', fontsize='large', fontweight='bold')
ax0.set_ylim([0.4,1])
ax0.set_xlabel('Epochs',fontsize='large')
ax0.set_ylabel('Accuracy',fontsize='large')
ax0.errorbar(epochs, mean_BE_acc_train_history, yerr=err_BE_acc_train_history,  label = "training accuracy",color='tab:blue', marker='o',markevery=mark_e,
             errorevery=e,  linewidth=1, markersize=mark_s)#, c=rgba[0]
ax0.errorbar(epochs, mean_BE_acc_test_history, yerr=err_BE_acc_test_history,  label = "test accuracy",color='tab:orange', marker='^',markevery=mark_e,
             errorevery=e,  linewidth=1, markersize=mark_s)#, c=rgba[-1]
ax0.legend(frameon=False, loc=(0.15,0.15), labelspacing=0)

ax0copy = ax0.twinx()  # instantiate a second axes that shares the same x-axis
ax0copy.set_ylim(0.4, 0.75)
# ax21copy.set_ylabel('Loss')
ax0copy.errorbar(epochs, mean_BE_loss_train_history, yerr=err_BE_loss_train_history,  label = "training loss",color='tab:green', marker='D',markevery=mark_e,
             errorevery=e,  linewidth=1, markersize=mark_s)# c=rgba[0],
ax0copy.errorbar(epochs, mean_BE_loss_test_history, yerr=err_BE_loss_test_history,  label = "test loss",color='tab:red', marker='s',markevery=mark_e,
             errorevery=e,  linewidth=1, markersize=mark_s)#, c=rgba[-1]
ax0copy.legend(frameon=False, loc=(0.15,0.03), labelspacing=0)



#ax1.set_title('')
ax1.text(-25, 1.03, 'b', fontsize='large', fontweight='bold')
ax1.set_ylim([0.4,1])
ax1.set_xlabel('Epochs',fontsize='large')
ax1.errorbar(epochs, mean_BE_EncodingFirst_acc_train_history, label = "training accuracy",color='tab:blue', marker='o',markevery=mark_e,
             yerr=err_BE_EncodingFirst_acc_train_history, errorevery=e,  linewidth=1, markersize=mark_s)
ax1.errorbar(epochs, mean_BE_EncodingFirst_acc_test_history, label = "test accuracy",color='tab:orange', marker='^',markevery=mark_e,
             yerr=err_BE_EncodingFirst_acc_test_history, errorevery=e, linewidth=1, markersize=mark_s)
ax1.legend(frameon=False, loc=(0.15,0.15), labelspacing=0)

ax1copy = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax1copy.set_ylim(0.4, 0.75)
ax1copy.set_ylabel('Loss',fontsize='large')
ax1copy.errorbar(epochs, mean_BE_EncodingFirst_loss_train_history, label = "training loss",color='tab:green', marker='D',markevery=mark_e,
             yerr=err_BE_EncodingFirst_loss_train_history, errorevery=e,  linewidth=1, markersize=mark_s)
ax1copy.errorbar(epochs, mean_BE_EncodingFirst_loss_test_history, label = "test loss",color='tab:red', marker='s',markevery=mark_e,
             yerr=err_BE_EncodingFirst_loss_test_history, errorevery=e,  linewidth=1, markersize=mark_s)
ax1copy.legend(frameon=False, loc=(0.15,0.03), labelspacing=0)

plt.tight_layout()
# plt.savefig('benchmark_mnist_std.pdf', bbox_inches='tight', pad_inches=0) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

n = 200
epochs = np.arange(1, n+1)
m = 10

err_BE_acc_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_train_history"][ind])
    err_BE_acc_train_history.append(np.std(E))

err_BE_acc_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_test_history"][ind])
    err_BE_acc_test_history.append(np.std(E))
    
err_BE_loss_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_train_history"][ind])
    err_BE_loss_train_history.append(np.std(E))

err_BE_loss_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_test_history"][ind])
    err_BE_loss_test_history.append(np.std(E))

#####################################################################################
    
err_BE_EncodingFirst_acc_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_train_history"][ind])
    err_BE_EncodingFirst_acc_train_history.append(np.std(E))

err_BE_EncodingFirst_acc_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["acc_test_history"][ind])
    err_BE_EncodingFirst_acc_test_history.append(np.std(E))
    
err_BE_EncodingFirst_loss_train_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_train_history"][ind])
    err_BE_EncodingFirst_loss_train_history.append(np.std(E))

err_BE_EncodingFirst_loss_test_history = []
for ind in range(n):
    E = []
    for i in range(1,m+1):
        data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
        E.append(data["loss_test_history"][ind])
    err_BE_EncodingFirst_loss_test_history.append(np.std(E))
mean_BE_acc_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_acc_train_history = mean_BE_acc_train_history + data["acc_train_history"][:]
mean_BE_acc_train_history = mean_BE_acc_train_history/m
mean_BE_acc_train_history

mean_BE_acc_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_acc_test_history = mean_BE_acc_test_history + data["acc_test_history"][:]
mean_BE_acc_test_history = mean_BE_acc_test_history/m
mean_BE_acc_test_history

mean_BE_EncodingFirst_acc_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_acc_train_history = mean_BE_EncodingFirst_acc_train_history + data["acc_train_history"][:]
mean_BE_EncodingFirst_acc_train_history = mean_BE_EncodingFirst_acc_train_history/m
mean_BE_EncodingFirst_acc_train_history

mean_BE_EncodingFirst_acc_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_acc_test_history = mean_BE_EncodingFirst_acc_test_history + data["acc_test_history"][:]
mean_BE_EncodingFirst_acc_test_history = mean_BE_EncodingFirst_acc_test_history/m

mean_BE_loss_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_loss_train_history = mean_BE_loss_train_history + data["loss_train_history"][:]
mean_BE_loss_train_history = mean_BE_loss_train_history/m
mean_BE_loss_train_history

mean_BE_loss_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_20220208_'+str(i)+'.mat','r')
    mean_BE_loss_test_history = mean_BE_loss_test_history + data["loss_test_history"][:]
mean_BE_loss_test_history = mean_BE_loss_test_history/m
mean_BE_loss_test_history

mean_BE_EncodingFirst_loss_train_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_loss_train_history = mean_BE_EncodingFirst_loss_train_history + data["loss_train_history"][:]
mean_BE_EncodingFirst_loss_train_history = mean_BE_EncodingFirst_loss_train_history/m
mean_BE_EncodingFirst_loss_train_history

mean_BE_EncodingFirst_loss_test_history = np.zeros(n)
for i in range(1,m+1):
    data = h5py.File('../data/FashionMNIST_BE_EncodingFirst_20220208_'+str(i)+'.mat','r')
    mean_BE_EncodingFirst_loss_test_history = mean_BE_EncodingFirst_loss_test_history + data["loss_test_history"][:]
mean_BE_EncodingFirst_loss_test_history = mean_BE_EncodingFirst_loss_test_history/m
# data1["acc_train_history"][:n];
# plt.rcParams["font.family"] = "Times New Roman"
# plt.rcParams['figure.figsize'] = 24, 9
plt.rcParams.update({'font.size': 24})

cmap = plt.cm.get_cmap('coolwarm')
rgba = cmap(np.linspace(0., 1.0, 2))

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True,
                                    figsize=(24, 8))
e = 3
mark_s = 7
mark_e = 6

#ax0.set_title('')
ax0.text(-25, 1.03, 'a', fontsize='large', fontweight='bold')
ax0.set_ylim([0.4,1])
ax0.set_xlabel('Epochs',fontsize='large')
ax0.set_ylabel('Accuracy',fontsize='large')
ax0.errorbar(epochs, mean_BE_acc_train_history, yerr=err_BE_acc_train_history,  label = "training accuracy",color='tab:blue', marker='o',markevery=mark_e,
             errorevery=e, linewidth=1, markersize=mark_s)#, c=rgba[0]
ax0.errorbar(epochs, mean_BE_acc_test_history, yerr=err_BE_acc_test_history,  label = "test accuracy",color='tab:orange', marker='^',markevery=mark_e,
             errorevery=e, linewidth=1, markersize=mark_s)#, c=rgba[-1]
ax0.legend(frameon=False, loc=(0.15,0.15), labelspacing=0)

ax0copy = ax0.twinx()  # instantiate a second axes that shares the same x-axis
ax0copy.set_ylim(0.3, 0.75)
# ax21copy.set_ylabel('Loss')
ax0copy.errorbar(epochs, mean_BE_loss_train_history, yerr=err_BE_loss_train_history,  label = "training loss",color='tab:green', marker='D',markevery=mark_e,
             errorevery=e, linewidth=1, markersize=mark_s)# c=rgba[0],
ax0copy.errorbar(epochs, mean_BE_loss_test_history, yerr=err_BE_loss_test_history,  label = "test loss",color='tab:red', marker='s',markevery=mark_e,
             errorevery=e, linewidth=1, markersize=mark_s)#, c=rgba[-1]
ax0copy.legend(frameon=False, loc=(0.15,0.03), labelspacing=0)



#ax1.set_title('')
ax1.text(-25, 1.03, 'b', fontsize='large', fontweight='bold')
ax1.set_ylim([0.4,1])
ax1.set_xlabel('Epochs',fontsize='large')
ax1.errorbar(epochs, mean_BE_EncodingFirst_acc_train_history, label = "training accuracy",color='tab:blue', marker='o',markevery=mark_e,
             yerr=err_BE_EncodingFirst_acc_train_history, errorevery=e, linewidth=1, markersize=mark_s)
ax1.errorbar(epochs, mean_BE_EncodingFirst_acc_test_history, label = "test accuracy",color='tab:orange', marker='^',markevery=mark_e,
             yerr=err_BE_EncodingFirst_acc_test_history, errorevery=e, linewidth=1, markersize=mark_s)
ax1.legend(frameon=False, loc=(0.15,0.15), labelspacing=0)

ax1copy = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax1copy.set_ylim(0.3, 0.75)
ax1copy.set_ylabel('Loss',fontsize='large')
ax1copy.errorbar(epochs, mean_BE_EncodingFirst_loss_train_history, label = "training loss",color='tab:green', marker='D',markevery=mark_e,
             yerr=err_BE_EncodingFirst_loss_train_history, errorevery=e, linewidth=1, markersize=mark_s)
ax1copy.errorbar(epochs, mean_BE_EncodingFirst_loss_test_history, label = "test loss",color='tab:red', marker='s',markevery=mark_e,
             yerr=err_BE_EncodingFirst_loss_test_history, errorevery=e, linewidth=1, markersize=mark_s)
ax1copy.legend(frameon=False, loc=(0.15,0.03), labelspacing=0)

plt.tight_layout()
# plt.savefig('benchmark_fashionmnist_std.pdf', bbox_inches='tight', pad_inches=0) 
plt.show()
